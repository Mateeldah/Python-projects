# %%
import pandas as pd
import numpy as np
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tmp_groupby_df=df.groupby(['Sex']).agg(Age_mean=('Age','mean')).reset_index()

df=df.merge(tmp_groupby_df,on=['Sex'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable

# %%
table = Prettyable()
table.field_names=["Name","Age","Gender","Location","Occupation"]
table.add_row(["Alice",25,"Female","Port","Lawyer"]) 
table.add_row(["Sammy",35,"Male","Uyo","Nurse"])
table.add_row(["Bob",30,"Male","Lagos","Dentist"])
table.add_row(["Eve",29,"Female","Owerri","Realtor"])
table.add_row(["Uzor",40,"Male","Abuja","Cobbler"])
table.add_row(["Tee",31,"Female","Canada","Data Analyst"])
print(table)
# Out:
# +-------+-----+--------+----------+--------------+
# |  Name | Age | Gender | Location |  Occupation  |
# +-------+-----+--------+----------+--------------+
# | Alice |  25 | Female |   Port   |    Lawyer    |
# | Sammy |  35 |  Male  |   Uyo    |    Nurse     |
# |  Bob  |  30 |  Male  |  Lagos   |   Dentist    |
# |  Eve  |  29 | Female |  Owerri  |   Realtor    |
# |  Uzor |  40 |  Male  |  Abuja   |   Cobbler    |
# |  Tee  |  31 | Female |  Canada  | Data Analyst |
# +-------+-----+--------+----------+--------------+

# %%
from prettytable import PrettytTable
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 from prettytable import PrettytTable
#
# ImportError: cannot import name 'PrettytTable' from 'prettytable' (C:\Users\HP\anaconda3\Lib\site-packages\prettytable\__init__.py)

# %%
myTable = PrettyTable(["Student Name","Class","Section","Percentage"])

myTable.add_row(["Leonard","Python","A","91.2%"])
myTable.add_row(["Henry","Java","C","63.5%"])
myTable.add_row(["Chioma","Ccna","B","81.2%"])
myTable.add_row(["Bambi","X","B","81.2%"])
myTable.add_row(["Jude","X","A","91.2%"])
myTable.add_row(["Paul","Excel","B","71.2%"])
myTable.add_row(["Simon","X","A","98.2%"])
print(myTable)
# Out:
# +--------------+--------+---------+------------+
# | Student Name | Class  | Section | Percentage |
# +--------------+--------+---------+------------+
# |   Leonard    | Python |    A    |   91.2%    |
# |    Henry     |  Java  |    C    |   63.5%    |
# |    Chioma    |  Ccna  |    B    |   81.2%    |
# |    Bambi     |   X    |    B    |   81.2%    |
# |     Jude     |   X    |    A    |   91.2%    |
# |     Paul     | Excel  |    B    |   71.2%    |
# |    Simon     |   X    |    A    |   98.2%    |
# +--------------+--------+---------+------------+

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy 
from scipy import stats
df=pd.read_csv('mtcars.csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.sum()
# Out:
# Unnamed: 0    Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...
# mpg                                                       642.9
# cyl                                                         198
# disp                                                     7383.1
# hp                                                         4694
# drat                                                     115.09
# wt                                                      102.952
# qsec                                                     571.16
# vs                                                           14
# am                                                           13
# gear                                                        118
# carb                                                         90
# dtype: object

# %%
df.sum(axis=1,numeric_only=True)
# Out:
# 0     328.980
# 1     329.795
# 2     259.580
# 3     426.135
# 4     590.310
# 5     385.540
# 6     656.920
# 7     270.980
# 8     299.570
# 9     350.460
# 10    349.660
# 11    510.740
# 12    511.500
# 13    509.850
# 14    728.560
# 15    726.644
# 16    725.695
# 17    213.850
# 18    195.165
# 19    206.955
# 20    273.775
# 21    519.650
# 22    506.085
# 23    646.280
# 24    631.175
# 25    208.215
# 26    272.570
# 27    273.683
# 28    670.690
# 29    379.590
# 30    694.710
# 31    288.890
# dtype: float64

# %%
df.select_dtypes(include='number').median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
df.min()
# Out:
# Unnamed: 0    AMC Javelin
# mpg                  10.4
# cyl                     4
# disp                 71.1
# hp                     52
# drat                 2.76
# wt                  1.513
# qsec                 14.5
# vs                      0
# am                      0
# gear                    3
# carb                    1
# dtype: object

# %%
mpg=df.mpg
mpg.idxmax()
# Out:
# 19

# %%
df.std(numeric_only=True)
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
import pandas as pd
df=pd.DataFrame({'Name':['Alice','Bob','Charlie'],
'Math_Score':[80,90,85],
'English_Score':[70,75,78]})
df['Total'] =df[['Math_Score','English_Score']].sum(axis=1)
df
# Out:
#       Name  Math_Score  English_Score  Total
# 0    Alice          80             70    150
# 1      Bob          90             75    165
# 2  Charlie          85             78    163
